# %% [markdown]
# <a href="https://colab.research.google.com/github/harshhrawte/Perceptron/blob/main/Multilayer_perceptron_handwrittendigits_recognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.utils import to_categorical

# 1. Load MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# 2. Normalize the data to 0-1
x_train = x_train / 255.0
x_test = x_test / 255.0

# 3. One-hot encode labels
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# 4. Build the MLP model
model = Sequential([
    Flatten(input_shape=(28, 28)),   # Input layer (784)
    Dense(128, activation='relu'),   # Hidden layer 1
    Dense(64, activation='relu'),    # Hidden layer 2
    Dense(10, activation='softmax')  # Output layer
])

# 5. Compile the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# 6. Train the model
model.fit(x_train, y_train, epochs=10, batch_size=128, validation_split=0.1)

# 7. Evaluate the model
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f"\nTest accuracy: {test_acc:.4f}")
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.8241 - loss: 0.6318 - val_accuracy: 0.9585 - val_loss: 0.1459
# Epoch 2/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9541 - loss: 0.1570 - val_accuracy: 0.9693 - val_loss: 0.1009
# Epoch 3/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9693 - loss: 0.1042 - val_accuracy: 0.9737 - val_loss: 0.0882
# Epoch 4/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9784 - loss: 0.0728 - val_accuracy: 0.9743 - val_loss: 0.0842
# Epoch 5/10
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# Select a random index from test set
index = 9  # or use: index = np.random.randint(0, len(x_test))

# Show the digit
plt.imshow(x_test[index], cmap='gray')
plt.title("Input Image")
plt.axis('off')
plt.show()

# Make a prediction
prediction = model.predict(x_test[index].reshape(1, 28, 28))
predicted_digit = np.argmax(prediction)

print(f"Predicted digit: {predicted_digit}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Predicted digit: 9

# %%
import matplotlib.pyplot as plt
import numpy as np

# Find an index where the label is 7
target_digit = 7
indices = np.where(np.argmax(y_test, axis=1) == target_digit)[0]

# Pick the first (or any) index where label == 7
index = indices[0]  # you can use [1], [2]... to try others

# Show the digit image
plt.imshow(x_test[index], cmap='gray')
plt.title(f"Actual Digit: {target_digit}")
plt.axis('off')
plt.show()

# Predict the digit using the model
prediction = model.predict(x_test[index].reshape(1, 28, 28))
predicted_digit = np.argmax(prediction)

print(f"Predicted digit: {predicted_digit}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Predicted digit: 7

# %%
import matplotlib.pyplot as plt
import numpy as np

# Loop through digits 0 to 9
for digit in range(10):
    # Find the first index where the true label is the digit
    index = np.where(np.argmax(y_test, axis=1) == digit)[0][0]

    # Display the image
    plt.imshow(x_test[index], cmap='gray')
    plt.title(f"Actual Digit: {digit}")
    plt.axis('off')
    plt.show()

    # Predict the digit
    prediction = model.predict(x_test[index].reshape(1, 28, 28))
    predicted_digit = np.argmax(prediction)

    print(f"Actual digit: {digit} | Predicted digit: {predicted_digit}\n")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Actual digit: 0 | Predicted digit: 0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Actual digit: 1 | Predicted digit: 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Actual digit: 2 | Predicted digit: 2
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Actual digit: 3 | Predicted digit: 3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Actual digit: 4 | Predicted digit: 4
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Actual digit: 5 | Predicted digit: 6
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Actual digit: 6 | Predicted digit: 6
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Actual digit: 7 | Predicted digit: 7
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Actual digit: 8 | Predicted digit: 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Actual digit: 9 | Predicted digit: 9

# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam
import pandas as pd

# 1. Load MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# 2. Normalize the data
x_train = x_train / 255.0
x_test = x_test / 255.0

# 3. One-hot encode labels
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# 4. Hyperparameter sets to try
batch_sizes = [32, 64, 128]
learning_rates = [0.001, 0.01]
epochs_list = [5, 10]

# 5. Store results
results = []

# 6. Grid search over all combinations
for batch_size in batch_sizes:
    for lr in learning_rates:
        for epochs in epochs_list:
            # Build the model
            model = Sequential([
                Flatten(input_shape=(28, 28)),
                Dense(128, activation='relu'),
                Dense(64, activation='relu'),
                Dense(10, activation='softmax')
            ])

            # Compile with custom learning rate
            optimizer = Adam(learning_rate=lr)
            model.compile(optimizer=optimizer,
                          loss='categorical_crossentropy',
                          metrics=['accuracy'])

            # Train the model
            history = model.fit(x_train, y_train,
                                epochs=epochs,
                                batch_size=batch_size,
                                validation_split=0.1,
                                verbose=0)  # suppress output

            # Evaluate the model
            test_loss, test_acc = model.evaluate(x_test, y_test, verbose=0)

            # Store the result
            results.append({
                'Batch Size': batch_size,
                'Learning Rate': lr,
                'Epochs': epochs,
                'Train Accuracy': history.history['accuracy'][-1],
                'Val Accuracy': history.history['val_accuracy'][-1],
                'Test Accuracy': test_acc
            })

# 7. Create and display the results table
df = pd.DataFrame(results)
print("\n=== Accuracy Comparison Table ===\n")
print(df.to_string(index=False))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# ...

# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam
import pandas as pd

# 1. Load MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# 2. Normalize the data
x_train = x_train / 255.0
x_test = x_test / 255.0

# 3. One-hot encode labels
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# 4. Hyperparameter sets to try
batch_sizes = [32, 64, 128]
learning_rates = [0.001, 0.01]
epochs_list = [5, 10]
activation_functions = ['relu', 'tanh', 'sigmoid']

# 5. Store results
results = []

# 6. Grid search over all combinations
for batch_size in batch_sizes:
    for lr in learning_rates:
        for epochs in epochs_list:
            for activation_fn in activation_functions:
                # Build the model
                model = Sequential([
                    Flatten(input_shape=(28, 28)),
                    Dense(128, activation=activation_fn),
                    Dense(64, activation=activation_fn),
                    Dense(10, activation='softmax')
                ])

                # Compile with custom learning rate
                optimizer = Adam(learning_rate=lr)
                model.compile(optimizer=optimizer,
                              loss='categorical_crossentropy',
                              metrics=['accuracy'])

                # Train the model
                history = model.fit(x_train, y_train,
                                    epochs=epochs,
                                    batch_size=batch_size,
                                    validation_split=0.1,
                                    verbose=0)  # suppress output

                # Evaluate the model
                test_loss, test_acc = model.evaluate(x_test, y_test, verbose=0)

                # Store the result
                results.append({
                    'Batch Size': batch_size,
                    'Learning Rate': lr,
                    'Epochs': epochs,
                    'Activation': activation_fn,
                    'Train Accuracy': history.history['accuracy'][-1],
                    'Val Accuracy': history.history['val_accuracy'][-1],
                    'Test Accuracy': test_acc
                })

# 7. Create and display the results table
df = pd.DataFrame(results)
print("\n=== Accuracy Comparison Table ===\n")
print(df.to_string(index=False))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set style
sns.set(style="whitegrid")

# 1. Boxplot: Test Accuracy vs Activation Function
plt.figure(figsize=(10, 6))
sns.boxplot(x="Activation", y="Test Accuracy", data=df)
plt.title("Test Accuracy vs Activation Function")
plt.show()

# 2. Lineplot: Test Accuracy vs Learning Rate (grouped by Batch Size)
plt.figure(figsize=(10, 6))
sns.lineplot(x="Learning Rate", y="Test Accuracy", hue="Batch Size", data=df, marker='o')
plt.title("Test Accuracy vs Learning Rate (Grouped by Batch Size)")
plt.show()

# 3. Lineplot: Test Accuracy vs Epochs (grouped by Activation)
plt.figure(figsize=(10, 6))
sns.lineplot(x="Epochs", y="Test Accuracy", hue="Activation", data=df, marker='o')
plt.title("Test Accuracy vs Epochs (Grouped by Activation Function)")
plt.show()

# 4. Heatmap: Average Test Accuracy for combinations of Batch Size and Activation
pivot_table = df.pivot_table(values='Test Accuracy', index='Batch Size', columns='Activation')
plt.figure(figsize=(8, 6))
sns.heatmap(pivot_table, annot=True, fmt=".4f", cmap="viridis")
plt.title("Heatmap: Batch Size vs Activation Function (Test Accuracy)")
plt.show()
